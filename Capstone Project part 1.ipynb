# %% [markdown]
# ### John Lee
# ### BrainStation, Data Science
#
# # Notebook Part 1
#
# The NBA has been ramping up its use of data over the last decade. More teams than ever rely on data to take the most optimal shot or to gain any advantage on the defensive end. Following this trend, this notebook will attempt to model a niche segment of the game: predicting the effect of a timeout on a made field goal basket. A field goal basket is defined as any 2 point or 3 point basket that is made.
#
# With the result of the model, the following are to be investigated:
#
#    1. The features of the model that can be utilized in actual gameplay to give a strategic advantage
#    2. Predicting the outcome of a shot to create an optimal strategy for an offense and defense when calling a timeout
#    3. Scenarios in a game where the model would be useful
#
# This project will be using NBA play-by-play data scraped from the official [Basketball Reference website](https://www.basketball-reference.com/). Each row represents a single play of a game in chronological order, whereas the columns represent the details of the specific play (ex. rebounder, play made by home team, home score at the time). The data has been scraped and uploaded by an unknown Kaggle user and can be found [here](https://www.kaggle.com/datasets/schmadam97/nba-playbyplay-data-20182019?select=NBA_PBP_2020-21.csv). The data that is used will be four seasons worth of data (2018-2021).

# %% [markdown]
# ### Feature Engineering and Data Transformation
#
# ---

# %% [markdown]
# Before going into EDA, we will first transform the data by feature engineering the depedent variable. The dependent variable will be the result (make/miss) of the first shot attempt after a timeout.

# %%
import numpy as np
import pandas as pd
from scipy import stats

# %%
df1 = pd.read_csv('NBA_PBP_2017-18.csv')
df2 = pd.read_csv('NBA_PBP_2018-19.csv')
df3 = pd.read_csv('NBA_PBP_2019-20.csv')
df4 = pd.read_csv('NBA_PBP_2020-21.csv')

df = pd.concat([df1, df2, df3, df4], ignore_index=True)
df.head(45)
# Out:
#                              URL GameType                            Location  \
# 0   /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 1   /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 2   /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 3   /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 4   /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 5   /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 6   /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 7   /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 8   /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 9   /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 10  /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 11  /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 12  /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 13  /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 14  /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 15  /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 16  /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 17  /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 18  /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 19  /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 20  /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 21  /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 22  /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 23  /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 24  /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 25  /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 26  /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 27  /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 28  /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 29  /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 30  /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 31  /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 32  /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 33  /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 34  /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 35  /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 36  /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 37  /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 38  /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 39  /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 40  /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 41  /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 42  /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 43  /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
# 44  /boxscores/201710170CLE.html  regular  Quicken Loans Arena Cleveland Ohio
#
#                Date     Time WinningTeam  Quarter  SecLeft AwayTeam  \
# 0   October 17 2017  8:01 PM         CLE        1      720      BOS
# 1   October 17 2017  8:01 PM         CLE        1      704      BOS
# 2   October 17 2017  8:01 PM         CLE        1      687      BOS
# 3   October 17 2017  8:01 PM         CLE        1      683      BOS
# 4   October 17 2017  8:01 PM         CLE        1      681      BOS
# 5   October 17 2017  8:01 PM         CLE        1      678      BOS
# 6   October 17 2017  8:01 PM         CLE        1      662      BOS
# 7   October 17 2017  8:01 PM         CLE        1      659      BOS
# 8   October 17 2017  8:01 PM         CLE        1      651      BOS
# 9   October 17 2017  8:01 PM         CLE        1      651      BOS
# 10  October 17 2017  8:01 PM         CLE        1      648      BOS
# 11  October 17 2017  8:01 PM         CLE        1      632      BOS
# 12  October 17 2017  8:01 PM         CLE        1      632      BOS
# 13  October 17 2017  8:01 PM         CLE        1      621      BOS
# 14  October 17 2017  8:01 PM         CLE        1      605      BOS
# 15  October 17 2017  8:01 PM         CLE        1      596      BOS
# 16  October 17 2017  8:01 PM         CLE        1      589      BOS
# 17  October 17 2017  8:01 PM         CLE        1      573      BOS
# 18  October 17 2017  8:01 PM         CLE        1      571      BOS
# 19  October 17 2017  8:01 PM         CLE        1      569      BOS
# 20  October 17 2017  8:01 PM         CLE        1      562      BOS
# 21  October 17 2017  8:01 PM         CLE        1      554      BOS
# 22  October 17 2017  8:01 PM         CLE        1      532      BOS
# 23  October 17 2017  8:01 PM         CLE        1      529      BOS
# 24  October 17 2017  8:01 PM         CLE        1      529      BOS
# 25  October 17 2017  8:01 PM         CLE        1      529      BOS
# 26  October 17 2017  8:01 PM         CLE        1      529      BOS
# 27  October 17 2017  8:01 PM         CLE        1      514      BOS
# 28  October 17 2017  8:01 PM         CLE        1      513      BOS
# 29  October 17 2017  8:01 PM         CLE        1      501      BOS
# 30  October 17 2017  8:01 PM         CLE        1      498      BOS
# 31  October 17 2017  8:01 PM         CLE        1      482      BOS
# 32  October 17 2017  8:01 PM         CLE        1      469      BOS
# 33  October 17 2017  8:01 PM         CLE        1      462      BOS
# 34  October 17 2017  8:01 PM         CLE        1      448      BOS
# 35  October 17 2017  8:01 PM         CLE        1      448      BOS
# 36  October 17 2017  8:01 PM         CLE        1      442      BOS
# 37  October 17 2017  8:01 PM         CLE        1      442      BOS
# 38  October 17 2017  8:01 PM         CLE        1      435      BOS
# 39  October 17 2017  8:01 PM         CLE        1      431      BOS
# 40  October 17 2017  8:01 PM         CLE        1      429      BOS
# 41  October 17 2017  8:01 PM         CLE        1      426      BOS
# 42  October 17 2017  8:01 PM         CLE        1      419      BOS
# 43  October 17 2017  8:01 PM         CLE        1      419      BOS
# 44  October 17 2017  8:01 PM         CLE        1      405      BOS
#
#                                              AwayPlay  ...  \
# 0   Jump ball: K. Love vs. A. Horford (K. Irving g...  ...
# 1   K. Irving makes 2-pt jump shot from 10 ft (ass...  ...
# 2                                                 NaN  ...
# 3                     Defensive rebound by A. Horford  ...
# 4         G. Hayward misses 3-pt jump shot from 25 ft  ...
# 5                                                 NaN  ...
# 6                                                 NaN  ...
# 7                       Defensive rebound by J. Brown  ...
# 8   J. Tatum misses 2-pt layup from 2 ft (block by...  ...
# 9                           Offensive rebound by Team  ...
# 10  A. Horford makes 2-pt jump shot from 19 ft (as...  ...
# 11                                                NaN  ...
# 12                                                NaN  ...
# 13                                                NaN  ...
# 14                     Turnover by J. Brown (palming)  ...
# 15                                                NaN  ...
# 16                                                NaN  ...
# 17                J. Brown misses 2-pt dunk from 1 ft  ...
# 18                                                NaN  ...
# 19                                                NaN  ...
# 20      Personal foul by K. Love (drawn by K. Irving)  ...
# 21  G. Hayward makes 2-pt jump shot from 9 ft (ass...  ...
# 22                                                NaN  ...
# 23                                                NaN  ...
# 24                                                NaN  ...
# 25                                                NaN  ...
# 26                                                NaN  ...
# 27              K. Irving misses 2-pt layup from 3 ft  ...
# 28                                                NaN  ...
# 29                                                NaN  ...
# 30                    Defensive rebound by A. Horford  ...
# 31          K. Irving makes 2-pt jump shot from 16 ft  ...
# 32                                                NaN  ...
# 33  J. Brown makes 2-pt dunk from 1 ft (assist by ...  ...
# 34                                                NaN  ...
# 35                    Defensive rebound by G. Hayward  ...
# 36       Personal foul by K. Love (drawn by J. Brown)  ...
# 37                                                NaN  ...
# 38        A. Horford misses 3-pt jump shot from 25 ft  ...
# 39                     Offensive rebound by K. Irving  ...
# 40          J. Brown misses 3-pt jump shot from 25 ft  ...
# 41                                                NaN  ...
# 42                                                NaN  ...
# 43                                                NaN  ...
# 44                J. Brown makes 2-pt layup from 1 ft  ...
#
#                   EnterGame           LeaveGame        TurnoverPlayer  \
# 0                       NaN                 NaN                   NaN
# 1                       NaN                 NaN                   NaN
# 2                       NaN                 NaN                   NaN
# 3                       NaN                 NaN                   NaN
# 4                       NaN                 NaN                   NaN
# 5                       NaN                 NaN                   NaN
# 6                       NaN                 NaN                   NaN
# 7                       NaN                 NaN                   NaN
# 8                       NaN                 NaN                   NaN
# 9                       NaN                 NaN                   NaN
# 10                      NaN                 NaN                   NaN
# 11                      NaN                 NaN                   NaN
# 12                      NaN                 NaN                   NaN
# 13                      NaN                 NaN                   NaN
# 14                      NaN                 NaN  J. Brown - brownja02
# 15                      NaN                 NaN                   NaN
# 16                      NaN                 NaN                   NaN
# 17                      NaN                 NaN                   NaN
# 18                      NaN                 NaN                   NaN
# 19                      NaN                 NaN                   NaN
# 20                      NaN                 NaN                   NaN
# 21                      NaN                 NaN                   NaN
# 22                      NaN                 NaN                   NaN
# 23                      NaN                 NaN                   NaN
# 24                      NaN                 NaN                   NaN
# 25                      NaN                 NaN                   NaN
# 26                      NaN                 NaN                   NaN
# 27                      NaN                 NaN                   NaN
# 28                      NaN                 NaN                   NaN
# 29                      NaN                 NaN                   NaN
# 30                      NaN                 NaN                   NaN
# 31                      NaN                 NaN                   NaN
# 32                      NaN                 NaN    D. Rose - rosede01
# 33                      NaN                 NaN                   NaN
# 34                      NaN                 NaN                   NaN
# 35                      NaN                 NaN                   NaN
# 36                      NaN                 NaN                   NaN
# 37  T. Thompson - thomptr01  K. Love - loveke01                   NaN
# 38                      NaN                 NaN                   NaN
# 39                      NaN                 NaN                   NaN
# 40                      NaN                 NaN                   NaN
# 41                      NaN                 NaN                   NaN
# 42                      NaN                 NaN    D. Wade - wadedw01
# 43                      NaN                 NaN                   NaN
# 44                      NaN                 NaN                   NaN
#
#     TurnoverType TurnoverCause         TurnoverCauser  JumpballAwayPlayer  \
# 0            NaN           NaN                    NaN  K. Love - loveke01
# 1            NaN           NaN                    NaN                 NaN
# 2            NaN           NaN                    NaN                 NaN
# 3            NaN           NaN                    NaN                 NaN
# 4            NaN           NaN                    NaN                 NaN
# 5            NaN           NaN                    NaN                 NaN
# 6            NaN           NaN                    NaN                 NaN
# 7            NaN           NaN                    NaN                 NaN
# 8            NaN           NaN                    NaN                 NaN
# 9            NaN           NaN                    NaN                 NaN
# 10           NaN           NaN                    NaN                 NaN
# 11           NaN           NaN                    NaN                 NaN
# 12           NaN           NaN                    NaN                 NaN
# 13           NaN           NaN                    NaN                 NaN
# 14       palming           NaN                    NaN                 NaN
# 15           NaN           NaN                    NaN                 NaN
# 16           NaN           NaN                    NaN                 NaN
# 17           NaN           NaN                    NaN                 NaN
# 18           NaN           NaN                    NaN                 NaN
# 19           NaN           NaN                    NaN                 NaN
# 20           NaN           NaN                    NaN                 NaN
# 21           NaN           NaN                    NaN                 NaN
# 22           NaN           NaN                    NaN                 NaN
# 23           NaN           NaN                    NaN                 NaN
# 24           NaN           NaN                    NaN                 NaN
# 25           NaN           NaN                    NaN                 NaN
# 26           NaN           NaN                    NaN                 NaN
# 27           NaN           NaN                    NaN                 NaN
# 28           NaN           NaN                    NaN                 NaN
# 29           NaN           NaN                    NaN                 NaN
# 30           NaN           NaN                    NaN                 NaN
# 31           NaN           NaN                    NaN                 NaN
# 32     lost ball         steal  K. Irving - irvinky01                 NaN
# 33           NaN           NaN                    NaN                 NaN
# 34           NaN           NaN                    NaN                 NaN
# 35           NaN           NaN                    NaN                 NaN
# 36           NaN           NaN                    NaN                 NaN
# 37           NaN           NaN                    NaN                 NaN
# 38           NaN           NaN                    NaN                 NaN
# 39           NaN           NaN                    NaN                 NaN
# 40           NaN           NaN                    NaN                 NaN
# 41           NaN           NaN                    NaN                 NaN
# 42     traveling           NaN                    NaN                 NaN
# 43           NaN           NaN                    NaN                 NaN
# 44           NaN           NaN                    NaN                 NaN
#
#         JumpballHomePlayer           JumpballPoss Unnamed: 40
# 0   A. Horford - horfoal01  K. Irving - irvinky01         NaN
# 1                      NaN                    NaN         NaN
# 2                      NaN                    NaN         NaN
# 3                      NaN                    NaN         NaN
# 4                      NaN                    NaN         NaN
# 5                      NaN                    NaN         NaN
# 6                      NaN                    NaN         NaN
# 7                      NaN                    NaN         NaN
# 8                      NaN                    NaN         NaN
# 9                      NaN                    NaN         NaN
# 10                     NaN                    NaN         NaN
# 11                     NaN                    NaN         NaN
# 12                     NaN                    NaN         NaN
# 13                     NaN                    NaN         NaN
# 14                     NaN                    NaN         NaN
# 15                     NaN                    NaN         NaN
# 16                     NaN                    NaN         NaN
# 17                     NaN                    NaN         NaN
# 18                     NaN                    NaN         NaN
# 19                     NaN                    NaN         NaN
# 20                     NaN                    NaN         NaN
# 21                     NaN                    NaN         NaN
# 22                     NaN                    NaN         NaN
# 23                     NaN                    NaN         NaN
# 24                     NaN                    NaN         NaN
# 25                     NaN                    NaN         NaN
# 26                     NaN                    NaN         NaN
# 27                     NaN                    NaN         NaN
# 28                     NaN                    NaN         NaN
# 29                     NaN                    NaN         NaN
# 30                     NaN                    NaN         NaN
# 31                     NaN                    NaN         NaN
# 32                     NaN                    NaN         NaN
# 33                     NaN                    NaN         NaN
# 34                     NaN                    NaN         NaN
# 35                     NaN                    NaN         NaN
# 36                     NaN                    NaN         NaN
# 37                     NaN                    NaN         NaN
# 38                     NaN                    NaN         NaN
# 39                     NaN                    NaN         NaN
# 40                     NaN                    NaN         NaN
# 41                     NaN                    NaN         NaN
# 42                     NaN                    NaN         NaN
# 43                     NaN                    NaN         NaN
# 44                     NaN                    NaN         NaN
#
# [45 rows x 41 columns]

# %% [markdown]
# To simplify the data, we will drop the columns that are not relevant to a timeout or a make or miss of a shot or features that might cause multicollinearity (ie. Fouler and Fouled).

# %%
# %%time
#dropping columns that are not relevant
df = df.drop(['Blocker', 'Assister', 'FoulType', 'Fouled', 'ViolationType', 
              'FreeThrowShooter', 'FreeThrowOutcome', 'FreeThrowNum','EnterGame',
              'LeaveGame','TurnoverType','TurnoverCause','TurnoverCauser',
              'JumpballAwayPlayer','JumpballHomePlayer','JumpballPoss', 'URL','Shooter', 'ViolationPlayer', 'Game_duration_min'], axis=1)
df.drop(df.columns[df.columns.str.contains('unnamed',case = False)],axis = 1, inplace = True)
df
# Out:
# Wall time: 1.74 s
#                                   URL GameType  \
# 0        /boxscores/201710170CLE.html  regular
# 1        /boxscores/201710170CLE.html  regular
# 2        /boxscores/201710170CLE.html  regular
# 3        /boxscores/201710170CLE.html  regular
# 4        /boxscores/201710170CLE.html  regular
# ...                               ...      ...
# 1842317  /boxscores/202101150UTA.html  regular
# 1842318  /boxscores/202101150UTA.html  regular
# 1842319  /boxscores/202101150UTA.html  regular
# 1842320  /boxscores/202101150UTA.html  regular
# 1842321  /boxscores/202101150UTA.html  regular
#
#                                             Location             Date  \
# 0                 Quicken Loans Arena Cleveland Ohio  October 17 2017
# 1                 Quicken Loans Arena Cleveland Ohio  October 17 2017
# 2                 Quicken Loans Arena Cleveland Ohio  October 17 2017
# 3                 Quicken Loans Arena Cleveland Ohio  October 17 2017
# 4                 Quicken Loans Arena Cleveland Ohio  October 17 2017
# ...                                              ...              ...
# 1842317  Vivint Smart Home Arena Salt Lake City Utah  January 15 2021
# 1842318  Vivint Smart Home Arena Salt Lake City Utah  January 15 2021
# 1842319  Vivint Smart Home Arena Salt Lake City Utah  January 15 2021
# 1842320  Vivint Smart Home Arena Salt Lake City Utah  January 15 2021
# 1842321  Vivint Smart Home Arena Salt Lake City Utah  January 15 2021
#
#             Time WinningTeam  Quarter  SecLeft AwayTeam  \
# 0        8:01 PM         CLE        1      720      BOS
# 1        8:01 PM         CLE        1      704      BOS
# 2        8:01 PM         CLE        1      687      BOS
# 3        8:01 PM         CLE        1      683      BOS
# 4        8:01 PM         CLE        1      681      BOS
# ...          ...         ...      ...      ...      ...
# 1842317  9:00 PM         UTA        4       15      ATL
# 1842318  9:00 PM         UTA        4       13      ATL
# 1842319  9:00 PM         UTA        4       10      ATL
# 1842320  9:00 PM         UTA        4        0      ATL
# 1842321  9:00 PM         UTA        4        0      ATL
#
#                                                   AwayPlay  ...  \
# 0        Jump ball: K. Love vs. A. Horford (K. Irving g...  ...
# 1        K. Irving makes 2-pt jump shot from 10 ft (ass...  ...
# 2                                                      NaN  ...
# 3                          Defensive rebound by A. Horford  ...
# 4              G. Hayward misses 3-pt jump shot from 25 ft  ...
# ...                                                    ...  ...
# 1842317                                                NaN  ...
# 1842318                                                NaN  ...
# 1842319                                                NaN  ...
# 1842320                                 End of 4th quarter  ...
# 1842321                                        End of Game  ...
#
#                          Shooter        ShotType ShotOutcome  ShotDist Fouler  \
# 0                            NaN             NaN         NaN       NaN    NaN
# 1          K. Irving - irvinky01  2-pt jump shot        make      10.0    NaN
# 2             D. Rose - rosede01      2-pt layup        miss       1.0    NaN
# 3                            NaN             NaN         NaN       NaN    NaN
# 4         G. Hayward - haywago01  3-pt jump shot        miss      25.0    NaN
# ...                          ...             ...         ...       ...    ...
# 1842317  S. Harrison - harrish01      2-pt layup        miss       3.0    NaN
# 1842318                      NaN             NaN         NaN       NaN    NaN
# 1842319                      NaN             NaN         NaN       NaN    NaN
# 1842320                      NaN             NaN         NaN       NaN    NaN
# 1842321                      NaN             NaN         NaN       NaN    NaN
#
#                        Rebounder ReboundType  ViolationPlayer TimeoutTeam  \
# 0                            NaN         NaN              NaN         NaN
# 1                            NaN         NaN              NaN         NaN
# 2                            NaN         NaN              NaN         NaN
# 3         A. Horford - horfoal01   defensive              NaN         NaN
# 4                            NaN         NaN              NaN         NaN
# ...                          ...         ...              ...         ...
# 1842317                      NaN         NaN              NaN         NaN
# 1842318  U. Azubuike - azubuud01   offensive              NaN         NaN
# 1842319                      NaN         NaN              NaN         NaN
# 1842320                      NaN         NaN              NaN         NaN
# 1842321                      NaN         NaN              NaN         NaN
#
#                   TurnoverPlayer
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 1842317                      NaN
# 1842318                      NaN
# 1842319  U. Azubuike - azubuud01
# 1842320                      NaN
# 1842321                      NaN
#
# [1842322 rows x 24 columns]

# %% [markdown]
# In the data, we want to distinguish each play by the corresponding game. In order to do so, we will create a column that will label each play to its respective game.

# %%
# %%time
df['GameID'] = np.where(df['AwayPlay'] == 'End of Game', 'EndOfGame', None)
#Creating GameID column to distinguish games
# Out:
# Wall time: 125 ms

# %%
end_of_game_index = df.dropna(axis=0, subset=['GameID']).index

# %%
# %%time
# Populated GameID 
GameID = 1
PreviousGameIndex = -1
for i in end_of_game_index:
    df.iloc[(PreviousGameIndex+1):(i+1),-1] = GameID
    GameID += 1
    PreviousGameIndex = i
# Out:
# Wall time: 1min 59s

# %%
df.head(471)
# Out:
#                               URL GameType  \
# 0    /boxscores/201710170CLE.html  regular
# 1    /boxscores/201710170CLE.html  regular
# 2    /boxscores/201710170CLE.html  regular
# 3    /boxscores/201710170CLE.html  regular
# 4    /boxscores/201710170CLE.html  regular
# ..                            ...      ...
# 466  /boxscores/201710170CLE.html  regular
# 467  /boxscores/201710170CLE.html  regular
# 468  /boxscores/201710170CLE.html  regular
# 469  /boxscores/201710170CLE.html  regular
# 470  /boxscores/201710170GSW.html  regular
#
#                                Location             Date      Time  \
# 0    Quicken Loans Arena Cleveland Ohio  October 17 2017   8:01 PM
# 1    Quicken Loans Arena Cleveland Ohio  October 17 2017   8:01 PM
# 2    Quicken Loans Arena Cleveland Ohio  October 17 2017   8:01 PM
# 3    Quicken Loans Arena Cleveland Ohio  October 17 2017   8:01 PM
# 4    Quicken Loans Arena Cleveland Ohio  October 17 2017   8:01 PM
# ..                                  ...              ...       ...
# 466  Quicken Loans Arena Cleveland Ohio  October 17 2017   8:01 PM
# 467  Quicken Loans Arena Cleveland Ohio  October 17 2017   8:01 PM
# 468  Quicken Loans Arena Cleveland Ohio  October 17 2017   8:01 PM
# 469  Quicken Loans Arena Cleveland Ohio  October 17 2017   8:01 PM
# 470     Oracle Arena Oakland California  October 17 2017  10:30 PM
#
#     WinningTeam  Quarter  SecLeft AwayTeam  \
# 0           CLE        1      720      BOS
# 1           CLE        1      704      BOS
# 2           CLE        1      687      BOS
# 3           CLE        1      683      BOS
# 4           CLE        1      681      BOS
# ..          ...      ...      ...      ...
# 466         CLE        4        2      BOS
# 467         CLE        4        0      BOS
# 468         CLE        4        0      BOS
# 469         CLE        3        0      BOS
# 470         HOU        1      720      HOU
#
#                                               AwayPlay  ...        ShotType  \
# 0    Jump ball: K. Love vs. A. Horford (K. Irving g...  ...             NaN
# 1    K. Irving makes 2-pt jump shot from 10 ft (ass...  ...  2-pt jump shot
# 2                                                  NaN  ...      2-pt layup
# 3                      Defensive rebound by A. Horford  ...             NaN
# 4          G. Hayward misses 3-pt jump shot from 25 ft  ...  3-pt jump shot
# ..                                                 ...  ...             ...
# 466                     Offensive rebound by K. Irving  ...             NaN
# 467         K. Irving misses 3-pt jump shot from 26 ft  ...  3-pt jump shot
# 468                          Offensive rebound by Team  ...             NaN
# 469                                        End of Game  ...             NaN
# 470  Jump ball: Z. Pachulia vs. C. Capela (R. Ander...  ...             NaN
#
#     ShotOutcome ShotDist  Fouler               Rebounder ReboundType  \
# 0           NaN      NaN     NaN                     NaN         NaN
# 1          make     10.0     NaN                     NaN         NaN
# 2          miss      1.0     NaN                     NaN         NaN
# 3           NaN      NaN     NaN  A. Horford - horfoal01   defensive
# 4          miss     25.0     NaN                     NaN         NaN
# ..          ...      ...     ...                     ...         ...
# 466         NaN      NaN     NaN   K. Irving - irvinky01   offensive
# 467        miss     26.0     NaN                     NaN         NaN
# 468         NaN      NaN     NaN                    Team   offensive
# 469         NaN      NaN     NaN                     NaN         NaN
# 470         NaN      NaN     NaN                     NaN         NaN
#
#     ViolationPlayer  TimeoutTeam TurnoverPlayer GameID
# 0               NaN          NaN            NaN      1
# 1               NaN          NaN            NaN      1
# 2               NaN          NaN            NaN      1
# 3               NaN          NaN            NaN      1
# 4               NaN          NaN            NaN      1
# ..              ...          ...            ...    ...
# 466             NaN          NaN            NaN      1
# 467             NaN          NaN            NaN      1
# 468             NaN          NaN            NaN      1
# 469             NaN          NaN            NaN      1
# 470             NaN          NaN            NaN      2
#
# [471 rows x 25 columns]

# %% [markdown]
# We can confirm that each row has been grouped into their corresponding games.

# %% [markdown]
# To make the dependent variable via feature engineering, we need to run a for loop to crawl through all the rows of data and to find the instance of a shot after a timeout. In order to do so, the NaN values that correspond to the for loop need to be replaced in order for it to run.

# %%
df['AwayPlay']
# Out:
# 0          Jump ball: K. Love vs. A. Horford (K. Irving g...
# 1          K. Irving makes 2-pt jump shot from 10 ft (ass...
# 2                                                        NaN
# 3                            Defensive rebound by A. Horford
# 4                G. Hayward misses 3-pt jump shot from 25 ft
#                                  ...
# 1842317                                                  NaN
# 1842318                                                  NaN
# 1842319                                                  NaN
# 1842320                                   End of 4th quarter
# 1842321                                          End of Game
# Name: AwayPlay, Length: 1842322, dtype: object

# %%
df['AwayPlay'] = df['AwayPlay'].replace(np.nan, 0)

# %%
df['HomePlay'] = df['HomePlay'].replace(np.nan, 0)

# %%
df[['HomePlay','AwayPlay']]
# Out:
#                                                   HomePlay  \
# 0                                                        0
# 1                                                        0
# 2        D. Rose misses 2-pt layup from 1 ft (block by ...
# 3                                                        0
# 4                                                        0
# ...                                                    ...
# 1842317            S. Harrison misses 2-pt layup from 3 ft
# 1842318                   Offensive rebound by U. Azubuike
# 1842319  Turnover by U. Azubuike (bad pass; steal by O....
# 1842320                                                  0
# 1842321                                                  0
#
#                                                   AwayPlay
# 0        Jump ball: K. Love vs. A. Horford (K. Irving g...
# 1        K. Irving makes 2-pt jump shot from 10 ft (ass...
# 2                                                        0
# 3                          Defensive rebound by A. Horford
# 4              G. Hayward misses 3-pt jump shot from 25 ft
# ...                                                    ...
# 1842317                                                  0
# 1842318                                                  0
# 1842319                                                  0
# 1842320                                 End of 4th quarter
# 1842321                                        End of Game
#
# [1842322 rows x 2 columns]

# %%
# %%time
#Make column to indicate if timeout resulted in basket
df['FirstBasketAfterTO'] = 'n/a'
timeoutindexseries = df.dropna(axis=0, subset=['TimeoutTeam']).index
shotindexseries = df.dropna(axis=0, subset=['ShotType']).index
PreviousGameID = 1
for i in timeoutindexseries:
    differenceseries = shotindexseries - i
    timeoutshotindex = i+min(filter(lambda a: a > 0, differenceseries))
    if df['GameID'][timeoutshotindex] == df['GameID'][i]:
        if '3-pt' in df['ShotType'][timeoutshotindex] and df['ShotOutcome'][timeoutshotindex] == 'make' and df['HomePlay'][timeoutshotindex] != 0:
            typeofshot = '3Home'
        elif '3-pt' in df['ShotType'][timeoutshotindex] and df['ShotOutcome'][timeoutshotindex] == 'make' and df['AwayPlay'][timeoutshotindex] != 0:
            typeofshot = '3Away'
        elif '2-pt' in df['ShotType'][timeoutshotindex] and df['ShotOutcome'][timeoutshotindex] == 'make' and df['HomePlay'][timeoutshotindex] != 0:
            typeofshot = '2Home'
        elif '2-pt' in df['ShotType'][timeoutshotindex] and df['ShotOutcome'][timeoutshotindex] == 'make' and df['AwayPlay'][timeoutshotindex] != 0:
            typeofshot = '2Away'
        elif '3-pt' in df['ShotType'][timeoutshotindex] and df['ShotOutcome'][timeoutshotindex] == 'miss' and df['HomePlay'][timeoutshotindex] != 0:
            typeofshot = '3HMiss'
        elif '3-pt' in df['ShotType'][timeoutshotindex] and df['ShotOutcome'][timeoutshotindex] == 'miss' and df['AwayPlay'][timeoutshotindex] != 0:
            typeofshot = '3AMiss'
        elif '2-pt' in df['ShotType'][timeoutshotindex] and df['ShotOutcome'][timeoutshotindex] == 'miss' and df['HomePlay'][timeoutshotindex] != 0:
            typeofshot = '2HMiss'
        elif '2-pt' in df['ShotType'][timeoutshotindex] and df['ShotOutcome'][timeoutshotindex] == 'miss' and df['AwayPlay'][timeoutshotindex] != 0:
            typeofshot = '2AMiss'
        df['FirstBasketAfterTO'][i] = typeofshot
# Out:
# <timed exec>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Wall time: 9h 25min 59s

# %%
# %%time
df.to_csv('df1.csv', index=False)
# Out:
# Wall time: 15.5 s

# %% [markdown]
# The feature engineered dependent variable has been successfully created, but since it took almost 10 hours to run, the data was exported so that it can be read directly.
#
# This was the most complicated part of the project, as we had to filter through every single row and find the first shot after a timeout in the data that was after the index of each timeout but before the following timeout, then input the result in the same index as the timeout.
#
# We will move onto the second notebook (Capstone Project part 2) to further analyze this data.
